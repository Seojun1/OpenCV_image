# %% [markdown]
# # 환경설정
# Anaconda Prompt 에서 다음 명령 수행
# > pip install opencv-python

# %%
import cv2
cv2.__version__
# Out:
# '4.5.5'

# %% [markdown]
# # OpenCV (Computer Vision)
# 다양한 영상 (이밎) / 동영상 처리에 사용되는 오픈소스 라이브러리

# %% [markdown]
# # 1. 이미지 출력

# %%
import cv2
img = cv2.imread('img.jpg') # 해당 경로의 파일 읽어오기
cv2.imshow('img', img) # img 라는 제목의 창에 img 표시
key = cv2.waitKey(0) # 지정된 시간(ms)동안 사용자 키 입력 대기
print(key)
cv2.destroyAllWindows() # 모두 닫기
# Out:
# 113

# %% [markdown]
# ## 읽기 옵션
# 1. cv2.IMREAD_COLOR : 컬러 이미지 가져오기. 투명 영역은 무시 (기본값)
# 2. cv2.IMREAD_GRAYSCALE : 흑백 이미지
# 3. cv2.IMREAD_UNCHANGED : 투명 영역까지 포함

# %%
import cv2
img_color = cv2.imread('img.jpg', cv2.IMREAD_COLOR)
img_gray = cv2.imread('img.jpg', cv2.IMREAD_GRAYSCALE)
img_unchanged = cv2.imread('img.jpg', cv2.IMREAD_UNCHANGED)

cv2.imshow('img_color', img_color)
cv2.imshow('img_gray', img_gray)
cv2.imshow('img_unchagned', img_unchanged)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Shape
# 이미지의 height, width, channel 정보

# %%
import cv2
img = cv2.imread('img.jpg')
img.shape # 세로, 가로, Channel
# Out:
# (390, 640, 3)
